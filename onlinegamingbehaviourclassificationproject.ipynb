# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayshajasma123/ayisha-portfolio/blob/main/onlinegamingbehaviourclassificationproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
                                    ###CLASSIFICATION PROJECT###
                                 #ONLINE GAMING BEHAVIOUR DATASET#

# %%
#STEP 1:-IMPORT LIBRARIES

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#STEP 2:-LOAD DATASET

df=pd.read_csv("/content/online_gaming_behaviour_dataset.csv")
df
# Out:
#        PlayerID   Age  Gender Location   GameGenre  PlayTimeHours  \
# 0          9000   NaN    Male    Other    Strategy      16.271119
# 1          9001   NaN  Female      USA    Strategy       5.525961
# 2          9002   NaN  Female      USA      Sports       8.223755
# 3          9003   NaN    Male      USA      Action       5.265351
# 4          9004   NaN    Male   Europe      Action      15.531945
# ...         ...   ...     ...      ...         ...            ...
# 40029     49029  32.0    Male      USA    Strategy      20.619662
# 40030     49030  44.0  Female    Other  Simulation      13.539280
# 40031     49031  15.0  Female      USA         RPG       0.240057
# 40032     49032  34.0    Male      USA      Sports      14.017818
# 40033     49033  19.0    Male      USA      Sports      10.083804
#
#        InGamePurchases GameDifficulty  SessionsPerWeek  \
# 0                    0         Medium                6
# 1                    0         Medium                5
# ...

# %%
#STEP 3:-CONVERTING TARGET COLUMN TO NUMERICAL

mapping = {
    "Low": 0,
    "Medium": 1,
    "High": 2
}

df["EngagementLevel"] = df["EngagementLevel"].map(mapping)

# %%
df
# Out:
#        PlayerID   Age  Gender Location   GameGenre  PlayTimeHours  \
# 0          9000   NaN    Male    Other    Strategy      16.271119
# 1          9001   NaN  Female      USA    Strategy       5.525961
# 2          9002   NaN  Female      USA      Sports       8.223755
# 3          9003   NaN    Male      USA      Action       5.265351
# 4          9004   NaN    Male   Europe      Action      15.531945
# ...         ...   ...     ...      ...         ...            ...
# 40029     49029  32.0    Male      USA    Strategy      20.619662
# 40030     49030  44.0  Female    Other  Simulation      13.539280
# 40031     49031  15.0  Female      USA         RPG       0.240057
# 40032     49032  34.0    Male      USA      Sports      14.017818
# 40033     49033  19.0    Male      USA      Sports      10.083804
#
#        InGamePurchases GameDifficulty  SessionsPerWeek  \
# 0                    0         Medium                6
# 1                    0         Medium                5
# ...

# %%
#STEP 4:- DISPLAY BASIC INFO

df.head()
# Out:
#    PlayerID  Age  Gender Location GameGenre  PlayTimeHours  InGamePurchases  \
# 0      9000  NaN    Male    Other  Strategy      16.271119                0
# 1      9001  NaN  Female      USA  Strategy       5.525961                0
# 2      9002  NaN  Female      USA    Sports       8.223755                0
# 3      9003  NaN    Male      USA    Action       5.265351                1
# 4      9004  NaN    Male   Europe    Action      15.531945                0
#
#   GameDifficulty  SessionsPerWeek  AvgSessionDurationMinutes  PlayerLevel  \
# 0         Medium                6                        108           79
# 1         Medium                5                        144           11
# 2           Easy               16                        142           35
# 3           Easy                9                         85           57
# 4         Medium                2                        131           95
#
#    AchievementsUnlocked  EngagementLevel
# ...

# %%
df.tail()
# Out:
#        PlayerID   Age  Gender Location   GameGenre  PlayTimeHours  \
# 40029     49029  32.0    Male      USA    Strategy      20.619662
# 40030     49030  44.0  Female    Other  Simulation      13.539280
# 40031     49031  15.0  Female      USA         RPG       0.240057
# 40032     49032  34.0    Male      USA      Sports      14.017818
# 40033     49033  19.0    Male      USA      Sports      10.083804
#
#        InGamePurchases GameDifficulty  SessionsPerWeek  \
# 40029                0           Easy                4
# 40030                0           Hard               19
# 40031                1           Easy               10
# 40032                1         Medium                3
# 40033                0           Easy               13
#
#        AvgSessionDurationMinutes  PlayerLevel  AchievementsUnlocked  \
# 40029                         75           85                    14
# 40030                        114           71                    27
# ...

# %%
df.describe()
# Out:
#            PlayerID           Age  PlayTimeHours  InGamePurchases  \
# count  40034.000000  40023.000000   40023.000000     40034.000000
# mean   29016.500000     31.992779      12.024299         0.200854
# std    11556.964675     10.043786       6.914571         0.400644
# min     9000.000000     15.000000       0.000115         0.000000
# 25%    19008.250000     23.000000       6.067204         0.000000
# 50%    29016.500000     32.000000      12.007792         0.000000
# 75%    39024.750000     41.000000      17.963579         0.000000
# max    49033.000000     49.000000      23.999592         1.000000
#
#        SessionsPerWeek  AvgSessionDurationMinutes   PlayerLevel  \
# count     40034.000000               40034.000000  40034.000000
# mean          9.471774                  94.792252     49.655568
# std           5.763667                  49.011375     28.588379
# min           0.000000                  10.000000      1.000000
# ...

# %%
df.columns
# Out:
# Index(['PlayerID', 'Age', 'Gender', 'Location', 'GameGenre', 'PlayTimeHours',
#        'InGamePurchases', 'GameDifficulty', 'SessionsPerWeek',
#        'AvgSessionDurationMinutes', 'PlayerLevel', 'AchievementsUnlocked',
#        'EngagementLevel'],
#       dtype='object')

# %%
df.shape
# Out:
# (40034, 13)

# %%
print("no of rows:",df.shape[0])
print("no of columns:",df.shape[1])
# Out:
# no of rows: 40034
# no of columns: 13

# %%
df.dtypes
# Out:
# PlayerID                       int64
# Age                          float64
# Gender                        object
# Location                      object
# GameGenre                     object
# PlayTimeHours                float64
# InGamePurchases                int64
# GameDifficulty                object
# SessionsPerWeek                int64
# AvgSessionDurationMinutes      int64
# PlayerLevel                    int64
# AchievementsUnlocked           int64
# EngagementLevel                int64
# dtype: object

# %%
#STEP 5:- CHECK MISSING VALUE

df.isna().sum()
# Out:
# PlayerID                      0
# Age                          11
# Gender                        0
# Location                      0
# GameGenre                     0
# PlayTimeHours                11
# InGamePurchases               0
# GameDifficulty                0
# SessionsPerWeek               0
# AvgSessionDurationMinutes     0
# PlayerLevel                   0
# AchievementsUnlocked          0
# EngagementLevel               0
# dtype: int64

# %%
#STEP 6:- HANDLE MISSING VALUE

df = df.fillna(df.median(numeric_only=True))
df
# Out:
#        PlayerID   Age  Gender Location   GameGenre  PlayTimeHours  \
# 0          9000  32.0    Male    Other    Strategy      16.271119
# 1          9001  32.0  Female      USA    Strategy       5.525961
# 2          9002  32.0  Female      USA      Sports       8.223755
# 3          9003  32.0    Male      USA      Action       5.265351
# 4          9004  32.0    Male   Europe      Action      15.531945
# ...         ...   ...     ...      ...         ...            ...
# 40029     49029  32.0    Male      USA    Strategy      20.619662
# 40030     49030  44.0  Female    Other  Simulation      13.539280
# 40031     49031  15.0  Female      USA         RPG       0.240057
# 40032     49032  34.0    Male      USA      Sports      14.017818
# 40033     49033  19.0    Male      USA      Sports      10.083804
#
#        InGamePurchases GameDifficulty  SessionsPerWeek  \
# 0                    0         Medium                6
# 1                    0         Medium                5
# ...

# %%
#STEP 7:- EDA-EXPLORATORY DATA ANALYSIS

#BARPLOTS FOR CATEGORICAL COLUMNS
categorical_cols=["Gender","Location","GameGenre","GameDifficulty"]
for col in categorical_cols:
    plt.figure(figsize=(8,5))
    df[col].value_counts().plot(kind="bar")
    plt.title(f"Value Counts for {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.xticks(rotation=45)
    plt.show()

# %%
#HISTOGRAM FOR NUMERICAL COLUMNS

numerical_cols=["PlayerID","Age","PlayTimeHours","InGamePurchases","SessionsPerWeek","AvgSessionDurationMinutes","PlayerLevel","AchievementsUnlocked"]
for col in numerical_cols:
  plt.figure(figsize=(8,5))
  sns.histplot(df[col],kde=True,bins=30)
  plt.title("Histogram of "+col)
  plt.show()

# %%
#STEP 8:-LABEL ENCODING

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in df.select_dtypes(include="object"):
    df[col] = le.fit_transform(df[col])

# %%
#STEP 9:-SPLIT FEATURES(X) AND TARGETS(Y)

x=df.iloc[:,:-1]
x
# Out:
#        PlayerID   Age  Gender  Location  GameGenre  PlayTimeHours  \
# 0          9000  32.0       1         2          4      16.271119
# 1          9001  32.0       0         3          4       5.525961
# 2          9002  32.0       0         3          3       8.223755
# 3          9003  32.0       1         3          0       5.265351
# 4          9004  32.0       1         1          0      15.531945
# ...         ...   ...     ...       ...        ...            ...
# 40029     49029  32.0       1         3          4      20.619662
# 40030     49030  44.0       0         2          2      13.539280
# 40031     49031  15.0       0         3          1       0.240057
# 40032     49032  34.0       1         3          3      14.017818
# 40033     49033  19.0       1         3          3      10.083804
#
#        InGamePurchases  GameDifficulty  SessionsPerWeek  \
# 0                    0               2                6
# 1                    0               2                5
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0        1
# 1        1
# 2        2
# 3        1
# 4        1
#         ..
# 40029    1
# 40030    2
# 40031    2
# 40032    1
# 40033    1
# Name: EngagementLevel, Length: 40034, dtype: int64

# %%
#STEP 10:- TRAIN,TEST,SPLIT

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#STEP 11:- APPLY STANDARDSCALER

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
#STEP 12:- TRAIN ALL CLASSIFICATION MODELS

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

models={"Logistic Regression":LogisticRegression(max_iter=2000,solver="saga"),"KNN":KNeighborsClassifier(),"DecisionTree":DecisionTreeClassifier(),"RandomForest":RandomForestClassifier(),"SVM":SVC(),"NaiveBayes":GaussianNB()}

accuracy_scores={}
for name,model in models.items():
  model.fit(x_train,y_train)
  y_pred=model.predict(x_test)
  accuracy_scores[name]=accuracy_score(y_test,y_pred)

# %%
#STEP 13:- ACCURACY TABLE
accuracy_scores
# Out:
# {'Logistic Regression': 0.8212813787935557,
#  'KNN': 0.7500936680404646,
#  'DecisionTree': 0.8241538653678032,
#  'RandomForest': 0.9077057574622206,
#  'SVM': 0.8918446359435493,
#  'NaiveBayes': 0.8433870363431997}

# %%
#STEP 14:- BARPLOT FOR MODEL ACCURACIES

plt.bar(accuracy_scores.keys(),accuracy_scores.values())
plt.xticks(rotation=45)
plt.ylabel("Accuracy")
plt.title("Comparison of Classification Models")
plt.show()

# %%
#STEP 15:- IDENTIFY BEST MODEL

best_model_name=max(accuracy_scores,key=accuracy_scores.get)
best_model_accuracy=accuracy_scores[best_model_name]
best_model_name,best_model_accuracy
# Out:
# ('RandomForest', 0.9077057574622206)

# %%
#STEP 16:- RETRAIN BEST MODEL

best_model=models[best_model_name]
best_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
#STEP 17:- EVALUATE BEST MODEL

y_pred_best=best_model.predict(x_test)

# %%
#CONFUSION MATRIX
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cm=confusion_matrix(y_test,y_pred)
print(cm)

#PLOT CONFUSION MATRIX
disp=ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title("Confusion Matrix")
plt.show()
# Out:
# [[1448  592   53]
#  [ 100 3714   65]
#  [  53  391 1591]]

# %%
#CLASSIFICATION REPORT
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_best))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89      2093
#            1       0.90      0.95      0.92      3879
#            2       0.92      0.87      0.89      2035
#
#     accuracy                           0.91      8007
#    macro avg       0.91      0.90      0.90      8007
# weighted avg       0.91      0.91      0.91      8007

# %%
#STEP 18:- ACTUAL AND PREDICTED DATAFRAME

comparison_df=pd.DataFrame({"Actual":y_test.values,"Predicted":y_pred_best})
comparison_df
# Out:
#       Actual  Predicted
# 0          1          1
# 1          1          1
# 2          1          0
# 3          1          1
# 4          1          1
# ...      ...        ...
# 8002       1          1
# 8003       2          2
# 8004       1          1
# 8005       1          1
# 8006       1          1
#
# [8007 rows x 2 columns]
